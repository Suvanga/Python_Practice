# %%
import pandas as pd

df = pd.read_csv('orders.csv')

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
df["Country"] #accessing a single column which has been stored as a pandas Series
set(df["Country"]) #gives unique values in the column
# Out:
# {'Argentina',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Colombia',
#  'Egypt',
#  'France',
#  'Germany',
#  'India',
#  'Iran',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Pakistan',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Saudi Arabia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'UAE',
#  'UK',
#  'USA',
#  'Ukraine'}

# %%
df[["Country", "Product"]] #we can also reference by multiple columns and it gives us a new set of dataframe

#THAT IS HOW WE INDEX COLUMNS IN PANDAS DATAFRAME
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3],[1,4,9])
plt.title("Quick test")
plt.xlabel("x"); plt.ylabel("y")
plt.show()  # optional, but fine

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.iloc[1]

#iloc is used for indexing rows and columns by position This is going to g
# Out:
# OrderID                1002
# CustomerName      Sarah Lee
# Product          Headphones
# Category        Electronics
# Quantity                  2
# Price                 150.0
# OrderDate        2024-06-03
# Shipped                  No
# Country              Canada
# Name: 1, dtype: object

# %%
list(df.iloc[1])
# Out:
# [np.int64(1002),
#  'Sarah Lee',
#  'Headphones',
#  'Electronics',
#  np.int64(2),
#  np.float64(150.0),
#  '2024-06-03',
#  'No',
#  'Canada']

# %%
# I can also try to get singlee value and search with the help of column it is associated to 
df.iloc[1]["Country"] #gives the country value in the 1st row
#referencing by column name
# Out:
# 'Canada'
