# %%
import matplotlib.pyplot as plt

x= [1,2,3]
y= [1,4,9]

plt.plot(x,y)
plt.title("Quick test")
# Out:
# Text(0.5, 1.0, 'Quick test')

# %%
import numpy as np
x = np.array([2023, 2024, 2025, 2026])
y= np.array([15, 25, 30 , 20])

plt.plot(x,y)
plt.show()
